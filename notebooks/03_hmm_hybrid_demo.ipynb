# %% [markdown]
# # HMM Hybrid Demo\n\nThis notebook demonstrates the HMM overlay on top of RLM standardized scores (S_D, S_V, S_L, S_G).

# %% [markdown]
# ## 1) State probability heatmaps vs regime_key\n- Build factors and forecast features.\n- Fit HMM on in-sample window.\n- Plot state posterior probabilities and regime labels over time.

# %% [markdown]
# ## 2) Position sizing modulation chart\n- Compute `hmm_confidence` and `hmm_size_mult` from `apply_roee_policy`.\n- Plot base vs HMM-modulated size fraction.

# %% [markdown]
# ## 3) Transition-risk gating effect\n- Show rows where HMM confidence is below threshold and trades are gated.\n- Compare summary metrics with/without HMM gating.
